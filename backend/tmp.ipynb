# %%
from backend.model_utils import get_model
import torch

# %%
derain_model = get_model()
derain_model.eval()
derain_model.to('cpu')
# Out:
# Making model...
# ipt(
#   (sub_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (add_mean): MeanShift(3, 3, kernel_size=(1, 1), stride=(1, 1))
#   (head): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): ReLU(inplace=True)
#           (2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         )
#       )
#       (2): ResBlock(
#         (body): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#           (1): ReLU(inplace=True)
#           (2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         )
#       )
#     )
#   )
#   (body): VisionTransformer(
#     (linear_encoding): Linear(in_features=576, out_features=576, bias=True)
#     (mlp_head): Sequential(
#       (0): Linear(in_features=576, out_features=2304, bias=True)
#       (1): Dropout(p=0, inplace=False)
#       (2): ReLU()
#       (3): Linear(in_features=2304, out_features=576, bias=True)
#       (4): Dropout(p=0, inplace=False)
#     )
#     (query_embed): Embedding(1, 147456)
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=576, out_features=576, bias=False)
#           )
#           (linear1): Linear(in_features=576, out_features=2304, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=2304, out_features=576, bias=True)
#           (norm1): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#         )
#       )
#     )
#     (decoder): TransformerDecoder(
#       (layers): ModuleList(
#         (0-11): 12 x TransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=576, out_features=576, bias=False)
#           )
#           (multihead_attn): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=576, out_features=576, bias=False)
#           )
#           (linear1): Linear(in_features=576, out_features=2304, bias=True)
#           (dropout): Dropout(p=0, inplace=False)
#           (linear2): Linear(in_features=2304, out_features=576, bias=True)
#           (norm1): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#           (norm3): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0, inplace=False)
#           (dropout2): Dropout(p=0, inplace=False)
#           (dropout3): Dropout(p=0, inplace=False)
#         )
#       )
#     )
#     (position_encoding): LearnedPositionalEncoding(
#       (pe): Embedding(256, 576)
#     )
#     (dropout_layer1): Dropout(p=0, inplace=False)
#   )
#   (tail): ModuleList(
#     (0): Sequential(
#       (0): Upsampler()
#       (1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
img = torch.load("img.pt")['img']
import matplotlib.pyplot as plt
img = img.squeeze().permute(1,2,0).detach().numpy()/255.0
plt.imshow(img)

# %%
import torch.nn as nn
for name, layer in derain_model.named_modules():
    print(name)
# Out:
# sub_mean
# add_mean
# head
# head.0
# head.0.0
# head.0.1
# head.0.1.body
# head.0.1.body.0
# head.0.1.body.1
# head.0.1.body.2
# head.0.2
# head.0.2.body
# head.0.2.body.0
# head.0.2.body.2
# body
# body.linear_encoding
# body.mlp_head
# body.mlp_head.0
# body.mlp_head.1
# body.mlp_head.2
# body.mlp_head.3
# body.mlp_head.4
# body.query_embed
# body.encoder
# body.encoder.layers
# body.encoder.layers.0
# body.encoder.layers.0.self_attn
# body.encoder.layers.0.self_attn.out_proj
# body.encoder.layers.0.linear1
# body.encoder.layers.0.dropout
# body.encoder.layers.0.linear2
# body.encoder.layers.0.norm1
# body.encoder.layers.0.norm2
# body.encoder.layers.0.dropout1
# body.encoder.layers.0.dropout2
# body.encoder.layers.1
# body.encoder.layers.1.self_attn
# body.encoder.layers.1.self_attn.out_proj
# body.encoder.layers.1.linear1
# body.encoder.layers.1.dropout
# body.encoder.layers.1.linear2
# body.encoder.layers.1.norm1
# body.encoder.layers.1.norm2
# body.encoder.layers.1.dropout1
# body.encoder.layers.1.dropout2
# body.encoder.layers.2
# body.encoder.layers.2.self_attn
# body.encoder.layers.2.self_attn.out_proj
# body.encoder.layers.2.linear1
# body.encoder.layers.2.dropout
# body.encoder.layers.2.linear2
# body.encoder.layers.2.norm1
# body.encoder.layers.2.norm2
# body.encoder.layers.2.dropout1
# body.encoder.layers.2.dropout2
# body.encoder.layers.3
# body.encoder.layers.3.self_attn
# body.encoder.layers.3.self_attn.out_proj
# body.encoder.layers.3.linear1
# body.encoder.layers.3.dropout
# body.encoder.layers.3.linear2
# body.encoder.layers.3.norm1
# body.encoder.layers.3.norm2
# body.encoder.layers.3.dropout1
# body.encoder.layers.3.dropout2
# body.encoder.layers.4
# body.encoder.layers.4.self_attn
# body.encoder.layers.4.self_attn.out_proj
# body.encoder.layers.4.linear1
# body.encoder.layers.4.dropout
# body.encoder.layers.4.linear2
# body.encoder.layers.4.norm1
# body.encoder.layers.4.norm2
# body.encoder.layers.4.dropout1
# body.encoder.layers.4.dropout2
# body.encoder.layers.5
# body.encoder.layers.5.self_attn
# body.encoder.layers.5.self_attn.out_proj
# body.encoder.layers.5.linear1
# body.encoder.layers.5.dropout
# body.encoder.layers.5.linear2
# body.encoder.layers.5.norm1
# body.encoder.layers.5.norm2
# body.encoder.layers.5.dropout1
# body.encoder.layers.5.dropout2
# body.encoder.layers.6
# body.encoder.layers.6.self_attn
# body.encoder.layers.6.self_attn.out_proj
# body.encoder.layers.6.linear1
# body.encoder.layers.6.dropout
# body.encoder.layers.6.linear2
# body.encoder.layers.6.norm1
# body.encoder.layers.6.norm2
# body.encoder.layers.6.dropout1
# body.encoder.layers.6.dropout2
# body.encoder.layers.7
# body.encoder.layers.7.self_attn
# body.encoder.layers.7.self_attn.out_proj
# body.encoder.layers.7.linear1
# body.encoder.layers.7.dropout
# body.encoder.layers.7.linear2
# body.encoder.layers.7.norm1
# body.encoder.layers.7.norm2
# body.encoder.layers.7.dropout1
# body.encoder.layers.7.dropout2
# body.encoder.layers.8
# body.encoder.layers.8.self_attn
# body.encoder.layers.8.self_attn.out_proj
# body.encoder.layers.8.linear1
# body.encoder.layers.8.dropout
# body.encoder.layers.8.linear2
# body.encoder.layers.8.norm1
# body.encoder.layers.8.norm2
# body.encoder.layers.8.dropout1
# body.encoder.layers.8.dropout2
# body.encoder.layers.9
# body.encoder.layers.9.self_attn
# body.encoder.layers.9.self_attn.out_proj
# body.encoder.layers.9.linear1
# body.encoder.layers.9.dropout
# body.encoder.layers.9.linear2
# body.encoder.layers.9.norm1
# body.encoder.layers.9.norm2
# body.encoder.layers.9.dropout1
# body.encoder.layers.9.dropout2
# body.encoder.layers.10
# body.encoder.layers.10.self_attn
# body.encoder.layers.10.self_attn.out_proj
# body.encoder.layers.10.linear1
# body.encoder.layers.10.dropout
# body.encoder.layers.10.linear2
# body.encoder.layers.10.norm1
# body.encoder.layers.10.norm2
# body.encoder.layers.10.dropout1
# body.encoder.layers.10.dropout2
# body.encoder.layers.11
# body.encoder.layers.11.self_attn
# body.encoder.layers.11.self_attn.out_proj
# body.encoder.layers.11.linear1
# body.encoder.layers.11.dropout
# body.encoder.layers.11.linear2
# body.encoder.layers.11.norm1
# body.encoder.layers.11.norm2
# body.encoder.layers.11.dropout1
# body.encoder.layers.11.dropout2
# body.decoder
# body.decoder.layers
# body.decoder.layers.0
# body.decoder.layers.0.self_attn
# body.decoder.layers.0.self_attn.out_proj
# body.decoder.layers.0.multihead_attn
# body.decoder.layers.0.multihead_attn.out_proj
# body.decoder.layers.0.linear1
# body.decoder.layers.0.dropout
# body.decoder.layers.0.linear2
# body.decoder.layers.0.norm1
# body.decoder.layers.0.norm2
# body.decoder.layers.0.norm3
# body.decoder.layers.0.dropout1
# body.decoder.layers.0.dropout2
# body.decoder.layers.0.dropout3
# body.decoder.layers.1
# body.decoder.layers.1.self_attn
# body.decoder.layers.1.self_attn.out_proj
# body.decoder.layers.1.multihead_attn
# body.decoder.layers.1.multihead_attn.out_proj
# body.decoder.layers.1.linear1
# body.decoder.layers.1.dropout
# body.decoder.layers.1.linear2
# body.decoder.layers.1.norm1
# body.decoder.layers.1.norm2
# body.decoder.layers.1.norm3
# body.decoder.layers.1.dropout1
# body.decoder.layers.1.dropout2
# body.decoder.layers.1.dropout3
# body.decoder.layers.2
# body.decoder.layers.2.self_attn
# body.decoder.layers.2.self_attn.out_proj
# body.decoder.layers.2.multihead_attn
# body.decoder.layers.2.multihead_attn.out_proj
# body.decoder.layers.2.linear1
# body.decoder.layers.2.dropout
# body.decoder.layers.2.linear2
# body.decoder.layers.2.norm1
# body.decoder.layers.2.norm2
# body.decoder.layers.2.norm3
# body.decoder.layers.2.dropout1
# body.decoder.layers.2.dropout2
# body.decoder.layers.2.dropout3
# body.decoder.layers.3
# body.decoder.layers.3.self_attn
# body.decoder.layers.3.self_attn.out_proj
# body.decoder.layers.3.multihead_attn
# body.decoder.layers.3.multihead_attn.out_proj
# body.decoder.layers.3.linear1
# body.decoder.layers.3.dropout
# body.decoder.layers.3.linear2
# body.decoder.layers.3.norm1
# body.decoder.layers.3.norm2
# body.decoder.layers.3.norm3
# body.decoder.layers.3.dropout1
# body.decoder.layers.3.dropout2
# body.decoder.layers.3.dropout3
# body.decoder.layers.4
# body.decoder.layers.4.self_attn
# body.decoder.layers.4.self_attn.out_proj
# body.decoder.layers.4.multihead_attn
# body.decoder.layers.4.multihead_attn.out_proj
# body.decoder.layers.4.linear1
# body.decoder.layers.4.dropout
# body.decoder.layers.4.linear2
# body.decoder.layers.4.norm1
# body.decoder.layers.4.norm2
# body.decoder.layers.4.norm3
# body.decoder.layers.4.dropout1
# body.decoder.layers.4.dropout2
# body.decoder.layers.4.dropout3
# body.decoder.layers.5
# body.decoder.layers.5.self_attn
# body.decoder.layers.5.self_attn.out_proj
# body.decoder.layers.5.multihead_attn
# body.decoder.layers.5.multihead_attn.out_proj
# body.decoder.layers.5.linear1
# body.decoder.layers.5.dropout
# body.decoder.layers.5.linear2
# body.decoder.layers.5.norm1
# body.decoder.layers.5.norm2
# body.decoder.layers.5.norm3
# body.decoder.layers.5.dropout1
# body.decoder.layers.5.dropout2
# body.decoder.layers.5.dropout3
# body.decoder.layers.6
# body.decoder.layers.6.self_attn
# body.decoder.layers.6.self_attn.out_proj
# body.decoder.layers.6.multihead_attn
# body.decoder.layers.6.multihead_attn.out_proj
# body.decoder.layers.6.linear1
# body.decoder.layers.6.dropout
# body.decoder.layers.6.linear2
# body.decoder.layers.6.norm1
# body.decoder.layers.6.norm2
# body.decoder.layers.6.norm3
# body.decoder.layers.6.dropout1
# body.decoder.layers.6.dropout2
# body.decoder.layers.6.dropout3
# body.decoder.layers.7
# body.decoder.layers.7.self_attn
# body.decoder.layers.7.self_attn.out_proj
# body.decoder.layers.7.multihead_attn
# body.decoder.layers.7.multihead_attn.out_proj
# body.decoder.layers.7.linear1
# body.decoder.layers.7.dropout
# body.decoder.layers.7.linear2
# body.decoder.layers.7.norm1
# body.decoder.layers.7.norm2
# body.decoder.layers.7.norm3
# body.decoder.layers.7.dropout1
# body.decoder.layers.7.dropout2
# body.decoder.layers.7.dropout3
# body.decoder.layers.8
# body.decoder.layers.8.self_attn
# body.decoder.layers.8.self_attn.out_proj
# body.decoder.layers.8.multihead_attn
# body.decoder.layers.8.multihead_attn.out_proj
# body.decoder.layers.8.linear1
# body.decoder.layers.8.dropout
# body.decoder.layers.8.linear2
# body.decoder.layers.8.norm1
# body.decoder.layers.8.norm2
# body.decoder.layers.8.norm3
# body.decoder.layers.8.dropout1
# body.decoder.layers.8.dropout2
# body.decoder.layers.8.dropout3
# body.decoder.layers.9
# body.decoder.layers.9.self_attn
# body.decoder.layers.9.self_attn.out_proj
# body.decoder.layers.9.multihead_attn
# body.decoder.layers.9.multihead_attn.out_proj
# body.decoder.layers.9.linear1
# body.decoder.layers.9.dropout
# body.decoder.layers.9.linear2
# body.decoder.layers.9.norm1
# body.decoder.layers.9.norm2
# body.decoder.layers.9.norm3
# body.decoder.layers.9.dropout1
# body.decoder.layers.9.dropout2
# body.decoder.layers.9.dropout3
# body.decoder.layers.10
# body.decoder.layers.10.self_attn
# body.decoder.layers.10.self_attn.out_proj
# body.decoder.layers.10.multihead_attn
# body.decoder.layers.10.multihead_attn.out_proj
# body.decoder.layers.10.linear1
# body.decoder.layers.10.dropout
# body.decoder.layers.10.linear2
# body.decoder.layers.10.norm1
# body.decoder.layers.10.norm2
# body.decoder.layers.10.norm3
# body.decoder.layers.10.dropout1
# body.decoder.layers.10.dropout2
# body.decoder.layers.10.dropout3
# body.decoder.layers.11
# body.decoder.layers.11.self_attn
# body.decoder.layers.11.self_attn.out_proj
# body.decoder.layers.11.multihead_attn
# body.decoder.layers.11.multihead_attn.out_proj
# body.decoder.layers.11.linear1
# body.decoder.layers.11.dropout
# body.decoder.layers.11.linear2
# body.decoder.layers.11.norm1
# body.decoder.layers.11.norm2
# body.decoder.layers.11.norm3
# body.decoder.layers.11.dropout1
# body.decoder.layers.11.dropout2
# body.decoder.layers.11.dropout3
# body.position_encoding
# body.position_encoding.pe
# body.dropout_layer1
# tail
# tail.0
# tail.0.0
# tail.0.1

# %%
derain_model.head
# Out:
# ModuleList(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ResBlock(
#       (body): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       )
#     )
#     (2): ResBlock(
#       (body): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU(inplace=True)
#         (2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       )
#     )
#   )
# )

# %%
import torch
from torchvision.models import resnet50
from torchvision.models.feature_extraction import create_feature_extractor

x = torch.rand(1, 3, 224, 224)

model = derain_model

return_nodes = {
    "layer4.2.relu_2": "layer4"
}
model2 = create_feature_extractor(model, return_nodes=return_nodes)
intermediate_outputs = model2(x)
